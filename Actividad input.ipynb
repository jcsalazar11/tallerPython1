# %%
Departamento = input ("Escoge uno de los siguientes departamentos A) Antioquia B) Cundinamarca C) Quíndio D) Valle \n (por favor ingresar nombre completo): ").title()

if Departamento == "Antioquia":
    
    Ciudad = input ("Escoge una de las siguientes Ciudadades del departamento de {} A) Medellin B) Itagui c) Guatape\
    D)Bello\n (por favor ingresar nombre completo): ".format(Departamento)).title()
    
    if Ciudad == "Medellin":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Históricos \
        D)Música \n(por favor ingresa el interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Bandeja Paisa B) Calentao C) Sancocho\
            D) Mondongo \n(por favor ingresar nombre completo): ").title()
            
            if Plato == "Bandeja Paisa":
                
                print("La bandeja paisa es un Plato tipo de la región antioqueña se caracteriza por su abundancai por lo cual\
                es servida en una bandeja. Sus igrediente principales son: Arroz, Carne molida, Chicharron, Huevo frito, Tajada\
                de platano maduro y Arepa")
            
            if Plato == "Calentao":
                
                print("desayuno típico de Medellín, el curioso calentao. \
                Se trata de un Plato de alimentos que no se consumieron el día anterior.\
                En los hoteles  podrás encontrarlo en una mezcla de arroz, frijoles y huevos. \
                Te recomiendo acompañarlo de una arepa")
            
            if Plato == "Sancocho":
                
                print("Medellín es el paraíso de las sopas. No importa el clima, si está lloviendo o hace mucho sol, \
                si es para el desayuno, el almuerzo o la cena, lo que si es cierto es que es uno de los Platos clásicos\
                de la gastronomía de Antioquía. El sancocho lleva en cuanto a las verduras papa, yuca, plátano y mazorca.\
                En cuanto a las carnes lleva tres tipos, de pollo, cerdo y res. El resultado de mezclar y cocinar todo esto, \
                es un delicioso caldo cargado de mucha sustancia.")
            
            if Plato == "Mondongo":
                
                print("El mondongo es una sopa consistente que incluye  carne de cerdo, callos y chorizo.\
                Para que esta sopa llegue a ser una de las mejores se deben cocinar las carnes junto a las verduras\
                en una olla hasta que todo quede bien cocinado. El mondongo normalmente se acompaña con arroz, \
                aguacate y plátano. ")
            
                
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Cultivos\n(por favor ingresar nombre completo): ").title()
            
            if Fauna == "Tipos":
                
                print("Antioquia es una zona con mucha biodiversidad tiene 5 tipos de fauna: Aves, Mamiferos, Anfibios, insectos\
                 y Reptiles")
            
            if Fauna=="Animales":
                
                print("Entre los animales más exoticos de esta zona están los Tití gris, el Tigrillo y el Aramadillo de nueve bandas")
                
            if Fauna == "Plantas":
                
                print("Entre sus plantas están las Orquideas, árboles como Comino, Abarco y Cativo ")
                
            if Fauna == "Cultivos":
                
                Print("En {} los cultivos más imporantes son los de café y se esta empezando a investigar sobre cultivos de cannabis medicinal").format(Ciudad)
            
            
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
            if Historico == "Personaje Famoso":
                
                print ("Entre los personajes más famosos de esta zona esta Belisario Betancur (ex-presidente), Caterine Ibarguen\
                (medallista olímpica) y Ferando Botero (Pintor)")
                
            if Historico == "Dato Curioso":
                
                print ("Es la Ciudad colombiana con mayor cantidad de esculturas en pie.")
                
                
            if Historico == "Fundada":
                
                print ("Medellín fue fundada oficialmente el 2 de marzo de 1616. Pero no siempre se llamó así, \
                el primer nombre que recibió la Ciudad fue San Lorenzo de Aburrá.")
                
            if Historico == "General":
                
                print ("La Feria de las Flores es súper importante para Medellín ya que allí se realizan más de 140 eventos culturales, entre ellos:\
                el Festival Nacional de la Trova, el Desfile de Autos Antiguos y el tradicional Desfile de Silleteros.")
        
            if Interes == "Música" or "Musica":         
                Musica = input("Qué tipo de musica quieres conocer A)Trova B)Reggeton C) Pasillo\
                D) Carilera\n(por favor ingresar nombre completo: ").title()
            
            
    
    if Ciudad == "Itagui":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
                     
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Bandeja Paisa B) Calentao C) Sancocho\
            D) Mondongo \n(por favor ingresar nombre completo): ").title()
            
            if Plato == "Bandeja Paisa":
                
                print("La bandeja paisa es un Plato tipo de la región antioqueña se caracteriza por su abundancai por lo cual\
                es servida en una bandeja. Sus igrediente principales son: Arroz, Carne molida, Chicharron, Huevo frito, Tajada\
                de platano maduro y Arepa")
            
            if Plato == "Calentao":
                
                print("desayuno típico de Medellín, el curioso calentao. \
                Se trata de un Plato de alimentos que no se consumieron el día anterior.\
                En los hoteles  podrás encontrarlo en una mezcla de arroz, frijoles y huevos. \
                Te recomiendo acompañarlo de una arepa")
            
            if Plato == "Sancocho":
                
                print("Medellín es el paraíso de las sopas. No importa el clima, si está lloviendo o hace mucho sol, \
                si es para el desayuno, el almuerzo o la cena, lo que si es cierto es que es uno de los Platos clásicos\
                de la gastronomía de Antioquía. El sancocho lleva en cuanto a las verduras papa, yuca, plátano y mazorca.\
                En cuanto a las carnes lleva tres tipos, de pollo, cerdo y res. El resultado de mezclar y cocinar todo esto, \
                es un delicioso caldo cargado de mucha sustancia.")
            
            if Plato == "Mondongo":
                
                print("El mondongo es una sopa consistente que incluye  carne de cerdo, callos y chorizo.\
                Para que esta sopa llegue a ser una de las mejores se deben cocinar las carnes junto a las verduras\
                en una olla hasta que todo quede bien cocinado. El mondongo normalmente se acompaña con arroz, \
                aguacate y plátano. ")
        
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Cultivos\n(por favor ingresar nombre completo): ").title()
            
            if Fauna == "Tipos":
                
                print("Antioquia es una zona con mucha biodiversidad tiene 5 tipos de fauna: Aves, Mamiferos, Anfibios, insectos\
                 y Reptiles")
            
            if Fauna=="Animales":
                
                print("Entre los animales más exoticos de esta zona están los Tití gris, el Tigrillo y el Aramadillo de nueve bandas")
                
            if Fauna == "Plantas":
                
                print("Entre sus plantas están las Orquideas, árboles como Comino, Abarco y Cativo ")
                
            if Fauna == "Cultivos":
                
                Print("En {} los cultivos más imporantes son los de café y se esta empezando a investigar sobre cultivos \
                de cannabis medicinal").format(Ciudad)
            
        
        if Interes == "Dato Histórico" or Interes == "Dato Historico":      
            
                      
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
            if Historico == "Personaje Famoso":
                
                print ("Entre los personajes más famosos de esta zona esta Belisario Betancur (ex-presidente), Caterine Ibarguen\
                (medallista olímpica) y Ferando Botero (Pintor)")
                
            if Historico == "Dato Curioso":
                
                print ("Es la Ciudad colombiana con mayor cantidad de esculturas en pie.")
                
                
            if Historico == "Fundada":
                
                print ("Medellín fue fundada oficialmente el 2 de marzo de 1616. Pero no siempre se llamó así, \
                el primer nombre que recibió la Ciudad fue San Lorenzo de Aburrá.")
                
            if Historico == "General":
                
                print("La Feria de las Flores es súper importante para Medellín ya que allí se realizan más de 140\ eventos culturales, entre ellos:\
                el Festival Nacional de la Trova, el Desfile de Autos Antiguos y el tradicional Desfile de Silleteros.")
            
            
        
            
            
            if Interes == "Música" or "Musica":
                Musica = input("Qué tipo de musica quieres conocer A)Trova B)Reggeton C) Pasillo\
                D) Carilera\n(por favor ingresar nombre completo: ").title()
        
    if Ciudad == "Guatape":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Bandeja Paisa B) Calentao C) Sancocho\
            D) Mondongo \n(por favor ingresar nombre completo): ").title()
            
            if Plato == "Bandeja Paisa":
                
                print("La bandeja paisa es un Plato tipo de la región antioqueña se caracteriza por su abundancai por lo cual\
                es servida en una bandeja. Sus igrediente principales son: Arroz, Carne molida, Chicharron, Huevo frito, Tajada\
                de platano maduro y Arepa")
            
            if Plato == "Calentao":
                
                print("desayuno típico de Medellín, el curioso calentao. \
                Se trata de un Plato de alimentos que no se consumieron el día anterior.\
                En los hoteles  podrás encontrarlo en una mezcla de arroz, frijoles y huevos. \
                Te recomiendo acompañarlo de una arepa")
            
            if Plato == "Sancocho":
                
                print("Medellín es el paraíso de las sopas. No importa el clima, si está lloviendo o hace mucho sol, \
                si es para el desayuno, el almuerzo o la cena, lo que si es cierto es que es uno de los Platos clásicos\
                de la gastronomía de Antioquía. El sancocho lleva en cuanto a las verduras papa, yuca, plátano y mazorca.\
                En cuanto a las carnes lleva tres tipos, de pollo, cerdo y res. El resultado de mezclar y cocinar todo esto, \
                es un delicioso caldo cargado de mucha sustancia.")
            
            if Plato == "Mondongo":
                
                print("El mondongo es una sopa consistente que incluye  carne de cerdo, callos y chorizo.\
                Para que esta sopa llegue a ser una de las mejores se deben cocinar las carnes junto a las verduras\
                en una olla hasta que todo quede bien cocinado. El mondongo normalmente se acompaña con arroz, \
                aguacate y plátano. ")
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Cultivos\n(por favor ingresar nombre completo): ").title()
            
            
            if Fauna == "Tipos":
                
                print("Antioquia es una zona con mucha biodiversidad tiene 5 tipos de fauna: Aves, Mamiferos, Anfibios, insectos\
                 y Reptiles")
            
            if Fauna=="Animales":
                
                print("Entre los animales más exoticos de esta zona están los Tití gris, el Tigrillo y el Aramadillo de nueve bandas")
                
            if Fauna == "Plantas":
                
                print("Entre sus plantas están las Orquideas, árboles como Comino, Abarco y Cativo ")
                
            if Fauna == "Cultivos":
                
                Print("En {} los cultivos más imporantes son los de café y se esta empezando a investigar sobre cultivos de cannabis medicinal").format(Ciudad)
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
            
            if Historico == "Personaje Famoso":
                
                print ("Entre los personajes más famosos de esta zona esta Belisario Betancur (ex-presidente), Caterine Ibarguen\
                (medallista olímpica) y Ferando Botero (Pintor)")
                
            if Historico == "Dato Curioso":
                
                print ("Es la Ciudad colombiana con mayor cantidad de esculturas en pie.")
                
                
            if Historico == "Fundada":
                
                print ("Medellín fue fundada oficialmente el 2 de marzo de 1616. Pero no siempre se llamó así, \
                el primer nombre que recibió la Ciudad fue San Lorenzo de Aburrá.")
                
            if Historico == "General":
                
                 print("La Feria de las Flores es súper importante para Medellín ya que allí se realizan más de 140 eventos culturales, entre ellos:\
                 el Festival Nacional de la Trova, el Desfile de Autos Antiguos y el tradicional Desfile de Silleteros.")
            
            if Interes == "Música" or "Musica":
                
                Musica = input("Qué tipo de musica quieres conocer A)Trova B)Reggeton C) Pasillo\
                D) Carilera\n(por favor ingresar nombre completo: ").title()

    if Ciudad == "Bello":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
                
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Bandeja Paisa B) Calentao C) Sancocho\
            D) Mondongo \n(por favor ingresar nombre completo): ").title()
            
            if Plato == "Bandeja Paisa":
                
                print("La bandeja paisa es un Plato tipo de la región antioqueña se caracteriza por su abundancai por lo cual\
                es servida en una bandeja. Sus igrediente principales son: Arroz, Carne molida, Chicharron, Huevo frito, Tajada\
                de platano maduro y Arepa")
            
            if Plato == "Calentao":
                
                print("desayuno típico de Medellín, el curioso calentao. \
                Se trata de un Plato de alimentos que no se consumieron el día anterior.\
                En los hoteles  podrás encontrarlo en una mezcla de arroz, frijoles y huevos. \
                Te recomiendo acompañarlo de una arepa")
            
            if Plato == "Sancocho":
                
                print("Medellín es el paraíso de las sopas. No importa el clima, si está lloviendo o hace mucho sol, \
                si es para el desayuno, el almuerzo o la cena, lo que si es cierto es que es uno de los Platos clásicos\
                de la gastronomía de Antioquía. El sancocho lleva en cuanto a las verduras papa, yuca, plátano y mazorca.\
                En cuanto a las carnes lleva tres tipos, de pollo, cerdo y res. El resultado de mezclar y cocinar todo esto, \
                es un delicioso caldo cargado de mucha sustancia.")
            
            if Plato == "Mondongo":
                
                print("El mondongo es una sopa consistente que incluye  carne de cerdo, callos y chorizo.\
                Para que esta sopa llegue a ser una de las mejores se deben cocinar las carnes junto a las verduras\
                en una olla hasta que todo quede bien cocinado. El mondongo normalmente se acompaña con arroz, \
                aguacate y plátano. ")
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Cultivos\n(por favor ingresar nombre completo): ").title()
            
            if Fauna == "Tipos":
                
                print("Antioquia es una zona con mucha biodiversidad tiene 5 tipos de fauna: Aves, Mamiferos, Anfibios, insectos\
                 y Reptiles")
            
            if Fauna=="Animales":
                
                print("Entre los animales más exoticos de esta zona están los Tití gris, el Tigrillo y el Aramadillo de nueve bandas")
                
            if Fauna == "Plantas":
                
                print("Entre sus plantas están las Orquideas, árboles como Comino, Abarco y Cativo ")
                
            if Fauna == "Cultivos":
                
                Print("En {} los cultivos más imporantes son los de café y se esta empezando a investigar sobre cultivos de cannabis medicinal").format(Ciudad)
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
            if Historico == "Personaje Famoso":
                
                print ("Entre los personajes más famosos de esta zona esta Belisario Betancur (ex-presidente), Caterine Ibarguen\
                (medallista olímpica) y Ferando Botero (Pintor)")
                
            if Historico == "Dato Curioso":
                
                print ("Este municipio fue considerado como una de las 10 Ciudades del futuro y séptima por mejor gestión.")
                
                
            if Historico == "Fundada":
                
                print ("En 1913 Bello contaba ya con 5 000 habitantes y un inusitado crecimiento económico, \
                razones suficientes para acceder al título de Municipio, distinción que fue obtenida mediante la \
                Ordenanza 48 del 29 de abril de 1913.")
                
            if Historico == "General":
                
                print("La Feria de las Flores es súper importante para Medellín ya que allí se realizan más de 140\ eventos culturales, entre ellos:\
                el Festival Nacional de la Trova, el Desfile de Autos Antiguos y el tradicional Desfile de Silleteros.")
            
            
        if Interes == "Música" or "Musica":
            
            Musica = input("Qué tipo de musica quieres conocer A)Trova B)Reggeton C) Pasillo\
            D) Carilera\n(por favor ingresar nombre completo: ").title()
            
            
                              
            
            
if Departamento == "Cundinamarca":
                 
    Ciudad = input ("Escoge una de las siguientes Ciudadades del departamento de {} A) Ubate B) Sutatatusa c) Zipaquira\
    D)Calera\n (por favor ingresar nombre completo): ".format(Departamento)).title()
    
    if Ciudad == "Ubate" or  Ciudad == "Ubaté":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Quesos B) Gallina C) Longaniza\
            D) Rellena \n(por favor ingresar nombre completo): ").title()
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Aves\n(por favor ingresar nombre completo): ").title()
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
        if Interes == "Música" or "Musica":
            
            Musica = input("Qué tipo de musica quieres conocer A)Caranga B)Reggeton C) Cantina\
            D) Carilera\n(por favor ingresar nombre completo: ").title()
        

    
    if Ciudad == "Sutatausa":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Quesos B) Gallina C) Longaniza\
            D) Rellena \n(por favor ingresar nombre completo): ").title()
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Aves\n(por favor ingresar nombre completo): ").title()
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
        if Interes == "Música" or "Musica":
            
            Musica = input("Qué tipo de musica quieres conocer A)Caranga B)Reggeton C) Cantina\
            D) Carilera\n(por favor ingresar nombre completo: ").title()
        
        
        
    
    if Ciudad == "Zipaquirá" or  Ciudad == "Zipaquira":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Sobrebarriga B) Carmelito C) Papa Salada\
            D) Loganiza \n(por favor ingresar nombre completo): ").title()
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Aves\n(por favor ingresar nombre completo): ").title()
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
        if Interes == "Música" or "Musica":
            
            Musica = input("Qué tipo de musica quieres conocer A)Caranga B)Reggeton C) Cantina\
            D) Carilera\n(por favor ingresar nombre completo: ").title()
    
    
    if Ciudad == "Calera":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Morcilla B) Carne C) Papa\
            D) Mazorca \n(por favor ingresar nombre completo): ").title()
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Aves\n(por favor ingresar nombre completo): ").title()
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
        if Interes == "Música" or "Musica":
            
            Musica = input("Qué tipo de musica quieres conocer A)Bolero B)Reggeton C) Cantina\
            D) Carilera\n(por favor ingresar nombre completo: ").title()
    
    
    
    
if Departamento == "Quíndio" or Departamento == "Quindio":
    
    Ciudad = input ("Escoge una de las siguientes Ciudadades del departamento de {} A) Armenia B) Filandia c) Salento\
    D)Montenegro\n (por favor ingresar nombre completo): ".format(Departamento)).title()
    
    if Ciudad == "Armenia":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Trucha B) Mondongo C) Sancocho\
            D) Sudado \n(por favor ingresar nombre completo): ").title()
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Aves\n(por favor ingresar nombre completo): ").title()
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
        if Interes == "Música" or "Musica":
            
            Musica = input("Qué tipo de musica quieres conocer A)Bandola B)Tiple C) Guitar\
            D) Carilera\n(por favor ingresar nombre completo: ").title()

    
    if Ciudad == "Filandia":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Trucha B) Mondongo C) Sancocho\
            D) Sudado \n(por favor ingresar nombre completo): ").title()
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Aves\n(por favor ingresar nombre completo): ").title()
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
        if Interes == "Música" or "Musica":
            
            Musica = input("Qué tipo de musica quieres conocer A)Bandola B)Tiple C) Guitar\
            D) Carilera\n(por favor ingresar nombre completo: ").title()
    
    if Ciudad == "Salento":
                
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Trucha B) Mondongo C) Sancocho\
            D) Sudado \n(por favor ingresar nombre completo): ").title()
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Aves\n(por favor ingresar nombre completo): ").title()
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
        if Interes == "Música" or "Musica":
            
            Musica = input("Qué tipo de musica quieres conocer A)Bandola B)Tiple C) Guitar\
            D) Carilera\n(por favor ingresar nombre completo: ").title()
    
    if Ciudad == "Montenegro":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Trucha B) Mondongo C) Sancocho\
            D) Sudado \n(por favor ingresar nombre completo): ").title()
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Aves\n(por favor ingresar nombre completo): ").title()
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
        if Interes == "Música" or "Musica":
            
            Musica = input("Qué tipo de musica quieres conocer A)Bandola B)Tiple C) Guitar\
            D) Carilera\n(por favor ingresar nombre completo: ").title()
    
    


if Departamento == "Valle":
    
    Ciudad = input ("Escoge una de las siguientes Ciudadades del departamento de {} A) Tuluá B) Buenaventura c) Cali\
    D) Yumbo\n (por favor ingresar nombre completo): ".format(Departamento)).title()
    
    if Ciudad == "Tuluá" or  Ciudad == "Tulua":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Sancocho B) Arroz Atollado C) Aborrajado\
            D) Marranitas \n(por favor ingresar nombre completo): ").title()
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Aves\n(por favor ingresar nombre completo): ").title()
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
        if Interes == "Música" or "Musica":
            
            Musica = input("Qué tipo de musica quieres conocer A)Salsa B)Salsa Choque C) Reggeton\
            D) Bambuco\n(por favor ingresar nombre completo: ").title()
    
    
    if Ciudad == "Buenaventura":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Arrechon B) Arroz Atollado C) Aborrajado\
            D) Marranitas \n(por favor ingresar nombre completo): ").title()
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Aves\n(por favor ingresar nombre completo): ").title()
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
        if Interes == "Música" or "Musica":
            
            Musica = input("Qué tipo de musica quieres conocer A)Salsa B)Salsa Choque C) Reggeton\
            D) Bambuco\n(por favor ingresar nombre completo: ").title()
            
    
    if Ciudad == "Cali":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Sancocho B) Arroz Atollado C) Aborrajado\
            D) Marranitas \n(por favor ingresar nombre completo): ").title()
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Aves\n(por favor ingresar nombre completo): ").title()
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
        if Interes == "Música" or "Musica":
            
            Musica = input("Qué tipo de musica quieres conocer A)Salsa B)Salsa Choque C) Reggeton\
            D) Bambuco\n(por favor ingresar nombre completo: ").title()
    
    
    if Ciudad == "Yumbo":
        
        Interes = input("Qué quieres saber sobre {} Ciudad A) Comida B) Fauna  C) Datos Historicos \
        D)Música \n(por favor ingresa interes completo): ".format(Ciudad)).title()
        
        if Interes == "Comida":
            
            Plato = input ("Sobre cual Plato quieres información A) Sancocho B) Arroz Atollado C) Aborrajado\
            D) Marranitas \n(por favor ingresar nombre completo): ").title()
            
            
        if Interes == "Fauna":
            
            Fauna = input ("Qué te interesa saber sobre la Fauna A) Tipos B) Animales C) Plantas\
            D) Aves\n(por favor ingresar nombre completo): ").title()
            
        if Interes == "Dato Histórico" or Interes == "Dato Historico":
            
            Historico = input("Qué quieres saber de historia A) Personajes Famosos B)Datos Curiosos C)Fundada\
            D)General\n(por favor ingresar nombre completo:").title()
            
        if Interes == "Música" or "Musica":
            
            Musica = input("Qué tipo de musica quieres conocer A)Salsa B)Salsa Choque C) Reggeton\
            D) Bambuco\n(por favor ingresar nombre completo: ").title()
# Out:
# Escoge uno de los siguientes departamentos A) Antioquia B) Cundinamarca C) Quíndio D) Valle
#  (por favor ingresar nombre completo): antioquia
# Escoge una de las siguientes Ciudadades del departamento de Antioquia A) Medellin B) Itagui c) Guatape    D)Bello
#  (por favor ingresar nombre completo): antioquia
